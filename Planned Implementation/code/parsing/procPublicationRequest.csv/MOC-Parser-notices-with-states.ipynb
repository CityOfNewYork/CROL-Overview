# %% [markdown]
# ![Image of Yaktocat](http://yuml.me/c961b9c3)

# %% [markdown]
# #States
# * INIT
#   * reads underlined text
#   * extracts context
#     * set next state = PREAMBLE
#
# * PREAMBLE
#   * reads PREAMBLE (NOTICE IS HEREBY...)
#   * extracts preamble
#     * set next state = PROCESS_ADVERTS
#
# * PROCESS_ADVERTS
#   * reads first key and first chunk of value
#     * set next state = PROCESS_ADVERT
#
# * PROCESS_ADVERT
#   * reads next chunk and evaluate.
#     ```
#     if ':' in chunk then
#        store current key/value
#        set current key, and initial value
#     else
#        append chunk to current-value
#     ```

# %%
from bs4 import BeautifulSoup as Soup
from IPython.display import HTML
import pandas as pd
import re
import pprint

# %%
class State:
    def run(self):
        # implement this for printing trace statements
        assert 0, "implement me"
        
    def next(self, input):
        assert 0, "implement me"
        
    def flush(self, record):
        raise Exception('wtf!')

# %%
class Adverts(State):
    
    def __init__(self):
        State.__init__(self)
        
        # Current key and Value
        # value can span multiple lines/paragraphs
        # so we have to build it up a chunk at a time.
        # The complete text of value is assumed when
        # a new key/value pair is detected
        self.key = None
        self.value = None
        
        # Current Advertisement
        self.advert = {}
        self.processingAdvert = False
        
    def run(self):
        print('Process ADVERTS')
        
    def flush(self, record):
        self.advert[self.key] = self.value.strip()
        record['adverts'].append(self.advert)
        
    def next(self, para, record):
        text = para.get_text(strip=True)
        if ':' in text:
            k, v = text.split(':', 1)
            k = k.strip()
            if k.lower().startswith('agency'):
                # the first time the code gets here
                # processingAdvert is False, set it to True
                # so that from now on getting here means
                # we've completed an Advertisement
                
                if self.processingAdvert:
                    # End of record reached
                    self.advert[self.key] = self.value.strip()
                    record['adverts'].append(self.advert)
                    self.advert = {}
                
                # yep, processing advertisements
                self.processingAdvert = True
                    
            else:
                # A new key/value pair is detected,
                # store current key/value pair
                self.advert[self.key] = self.value.strip()
                
            # Initialize the current key/value pair
            self.key, self.value = k, v
            
        else:
            # A value can span multiple lines
            # keep adding chunks to the current value
            # until a new key/value pair is detected...
            if self.value:
                self.value += text   # Append to a previous value
            else:
                self.value = text    # Otherwise set value
            
        return self
        

class Preamble(State):
    def run(self):
        print('PREAMBLE')
        
    def next(self, para, record):
        text = para.get_text(strip=True).strip()
        if 'NOTICE IS HEREBY' in text:
            record['preamble'] = text
            return Adverts()
        return self
            

class Init(State):
    def run(self):
        print('INIT')
        
    def next(self, para, record):
        if para.find_all('u'):
            record['context'] = para.get_text(strip=True).strip()
            return Preamble()
        return self

# %%
def parse_notice(soup):
    state = Init()
    record = { 'adverts': []}

    for para in soup.find_all('p'):
    #     state.run()
    #     print (para)
        state = state.next(para, record)
    #     print ('\n\n')

    state.flush(record)
    return record

# %%
fn = 'procPublicationRequest Oct-Dec 2014 (Updated) - Sheet1-2.csv'
rows = pd.read_csv(fn, header=0)

# %%
cols = ['RequestID', 'StartDate', 'EndDate',
        'AgencyCode', 'AgencyName', 'AgencyDivision',
        'TypeOfNoticeCode', 'TypeOfNoticeDescription',
        'ShortTitle', 'SectionID', 'SectionName',
        'DueDate', 'ConfirmationNumber',
        'AdditionalDescription', 'Address1']

# %%
rows = rows[cols]

# %%
mocs = rows['AgencyName'] == "Mayor's Office of Contract Services" 
# meets = rows['TypeOfNoticeDescription'] == "Meeting"
notices = rows['TypeOfNoticeDescription'] == "Notice"
# rows = rows[mocs]
# rows = rows[notices]

# %%
# from IPython.display import display
# badcount = 0
# for html in rows.AdditionalDescription.values:
#     if not isinstance(html, str):
#         badcount += 1
#     else:
#         display(HTML(html))
#         try:
#             parse_notice(Soup(html))
#         except Exception:
#             badcount += 1

# %%
import json
def scrape(row):
    output = None
    if row['AgencyName'] == "Mayor's Office of Contract Services" and \
       row['TypeOfNoticeDescription'] == "Notice":
        try:
            output = parse_notice(Soup(row.AdditionalDescription))
        except Exception :
            output = { 'error' : 'bad input' }
    row['output'] = json.dumps(output)
    return row

# %%
fix = rows.apply(scrape,1)

# %%
fix
# Out:
#        RequestID           StartDate             EndDate AgencyCode  \
# 0    20130621104    1/2/2014 0:00:00  12/31/2014 0:00:00         56
# 1    20131104111   9/29/2014 0:00:00   10/8/2014 0:00:00        OCS
# 2    20131104112  10/30/2014 0:00:00  11/12/2014 0:00:00        OCS
# 3    20131104113   12/1/2014 0:00:00  12/10/2014 0:00:00        OCS
# 4    20140109107    1/2/2014 0:00:00  12/31/2014 0:00:00        856
# 5    20140623102   10/6/2014 0:00:00   10/6/2014 0:00:00        NBM
# 6    20140623103  10/20/2014 0:00:00  10/20/2014 0:00:00        NBM
# 7    20140623104  10/27/2014 0:00:00  10/27/2014 0:00:00        NBM
# 8    20140814108   11/3/2014 0:00:00   11/3/2014 0:00:00        NBM
# 9    20140814109  11/10/2014 0:00:00  11/10/2014 0:00:00        NBM
# 10   20140815101  11/17/2014 0:00:00  11/17/2014 0:00:00        NBM
# 11   20140815102  11/24/2014 0:00:00  11/24/2014 0:00:00        NBM
# 12   20140902105  10/22/2014 0:00:00  10/28/2014 0:00:00        BER
# 13   20140911108  10/22/2014 0:00:00  10/29/2014 0:00:00        133
# 14   20140911109  12/10/2014 0:00:00  12/17/2014 0:00:00        133
# 15   20140915106   9/22/2014 0:00:00   10/3/2014 0:00:00        841
# 16   20140915108   9/22/2014 0:00:00   10/3/2014 0:00:00        841
# 17   20140916103   9/23/2014 0:00:00   10/6/2014 0:00:00         15
# 18   20140917102   10/7/2014 0:00:00  10/14/2014 0:00:00        NCB
# 19   20140917104   10/2/2014 0:00:00   10/8/2014 0:00:00        NCB
# 20   20140918101   10/1/2014 0:00:00   10/7/2014 0:00:00        NCB
# 21   20140918104   9/25/2014 0:00:00   10/8/2014 0:00:00         15
# 22   20140918106   10/8/2014 0:00:00   10/8/2014 0:00:00        866
# 23   20140919101   10/3/2014 0:00:00   10/3/2014 0:00:00         96
# 24   20140919102   10/3/2014 0:00:00   10/3/2014 0:00:00         25
# 25   20140919103  10/14/2014 0:00:00  10/20/2014 0:00:00        NCB
# 26   20140922102   10/1/2014 0:00:00  10/22/2014 0:00:00        841
# 27   20140923104   10/6/2014 0:00:00   10/6/2014 0:00:00        260
# 28   20140923106   10/8/2014 0:00:00   10/8/2014 0:00:00        866
# 460                                      LL 63 Posting          5
# 461         Brooklyn Public Hearings for Van companies          1
# 462          Public hearing for Brooklyn Commuter Vans          1
# 463     Brooklyn Public Hearing for Brooklyn Van Lines          1
# 464        Brooklyn Public Hearing for Ogo Van Service          1
# 465  Fuel Price Schedule the Week of December 22, 2014          5
# 466                                      LL 63 Posting          5
# 467                                      LL 63 Posting          5
# 468            corrected notice for 629 Courtlandt Ave          1
# 469  LL 63-Department of Parks and Recreation-New P...          5
# 470               Owner-Must-Drive OMD Rule amendments          4
# 471                         LL63-- DOF New Procurement          5
# 472  LL63-Department of Health and Mental Hygiene-N...          5
# 473                                      LL 63 Posting          5
# 474  DPR RECREATION CENTER AND TENNIS PERMIT DISCOU...          4
# 475  BOARD OF STANDARDS AND APPEALS PUBLIC HEARING ...          1
# 476                Community Investment Advisory Board          1
# 477                                       E-Hail Rules          4
#
#                                    SectionName              DueDate  \
# 0                         Property Disposition                  NaN
# 1                 Public Hearings and Meetings   10/8/2014 14:30:00
# 2                 Public Hearings and Meetings  11/12/2014 14:30:00
# 3                 Public Hearings and Meetings  12/10/2014 14:30:00
# 4                         Property Disposition                  NaN
# 5                 Public Hearings and Meetings                  NaN
# 6                 Public Hearings and Meetings                  NaN
# 7                 Public Hearings and Meetings                  NaN
# 8                 Public Hearings and Meetings                  NaN
# 9                 Public Hearings and Meetings                  NaN
# 10                Public Hearings and Meetings                  NaN
# 11                Public Hearings and Meetings                  NaN
# 12                Public Hearings and Meetings  10/29/2014 16:30:00
# 13                Public Hearings and Meetings   10/30/2014 9:30:00
# 14                Public Hearings and Meetings   12/18/2014 9:30:00
# 15                           Special Materials                  NaN
# 16                           Special Materials                  NaN
# 17                           Special Materials                  NaN
# 18                Public Hearings and Meetings                  NaN
# 19                Public Hearings and Meetings                  NaN
# 20                Public Hearings and Meetings                  NaN
# 21                           Special Materials                  NaN
# 22                Public Hearings and Meetings  10/22/2014 14:00:00
# 23   Agency Public Hearings on Contract Awards   10/16/2014 1:00:00
# 24   Agency Public Hearings on Contract Awards  10/16/2014 10:00:00
# 25                Public Hearings and Meetings                  NaN
# 26                Public Hearings and Meetings                  NaN
# 27   Agency Public Hearings on Contract Awards  10/15/2014 10:00:00
# 28                Public Hearings and Meetings  10/22/2014 14:00:00
# 29   Agency Public Hearings on Contract Awards  10/16/2014 10:00:00
# ..                                         ...                  ...
# 448               Public Hearings and Meetings                  NaN
# 449                          Special Materials                  NaN
# 450               Public Hearings and Meetings                  NaN
# 451                               Agency Rules                  NaN
# 452                          Special Materials                  NaN
# 453               Public Hearings and Meetings     1/6/2015 0:00:00
# 454                          Special Materials                  NaN
# 455               Public Hearings and Meetings                  NaN
# 456                               Agency Rules                  NaN
# 457                          Special Materials                  NaN
# 458               Public Hearings and Meetings                  NaN
# 459                          Special Materials                  NaN
# 460                          Special Materials                  NaN
# 461               Public Hearings and Meetings                  NaN
# 462               Public Hearings and Meetings                  NaN
# 463               Public Hearings and Meetings                  NaN
# 464               Public Hearings and Meetings                  NaN
# 465                          Special Materials                  NaN
# 466                          Special Materials                  NaN
# 467                          Special Materials                  NaN
# 468               Public Hearings and Meetings                  NaN
# 469                          Special Materials                  NaN
# 470                               Agency Rules                  NaN
# 471                          Special Materials                  NaN
# 472                          Special Materials                  NaN
# 473                          Special Materials                  NaN
# 474                               Agency Rules                  NaN
# 475               Public Hearings and Meetings   1/13/2015 10:00:00
# 476               Public Hearings and Meetings   1/13/2015 16:00:00
# 477                               Agency Rules                  NaN
#
#      ConfirmationNumber                              AdditionalDescription  \
# 0           20130621104  <p> <strong><strong><strong><strong><strong><s...
# 1           20131104111  <p> &nbsp;</p> <p> &nbsp;&nbsp;&nbsp;&nbsp;&nb...
# 2           20131104112  <p align=center"> &nbsp;</p> <p> &nbsp;&nbsp;&...
# 3           20131104113  <p> &nbsp;</p> <p> &nbsp;</p> <p> &nbsp;&nbsp;...
# 4           20140109107  <p> The Department of Citywide Administrative ...
# 5           20140623102  <p> <strong>City Planning Commission</strong><...
# 6           20140623103  <p> <strong>City Planning Commission</strong><...
# 7           20140623104  <p> <strong>City Planning Commission</strong><...
# 8           20140814108  <p> <strong>City Planning Commission</strong><...
# 9           20140814109  <p> <strong>City Planning Commission</strong><...
# 10          20140815101  <p> <strong>City Planning Commission</strong><...
# 11          20140815102  <p> <strong>City Planning Commission</strong><...
# 12          20140902105  <p> The next Board of Education Retirement Sys...
# 13          20140911108  <p> <span id=ctl00_cphbody_lblAdditionalDescr"...
# 14          20140911109  <p> <span id=ctl00_cphbody_lblAdditionalDescr"...
# 15          20140915106  <p> Pursuant to the Concession Rules of the Ci...
# 16          20140915108  <p> Pursuant to the Concession Rules of the Ci...
# 17          20140916103  <p> &nbsp;</p> <p> NOTICE OF ADVANCE PAYMENT O...
# 18          20140917102  <p> <strong>PUBLIC NOTICE IS HEREBY GIVEN </st...
# 19          20140917104  <p> <strong>PUBLIC NOTICE IS HEREBY GIVEN </st...
# 20          20140918101  <p> <strong>PUBLIC NOTICE IS HEREBY GIVEN </st...
# 21          20140918104  <p> NOTICE OF ADVANCE PAYMENT OF AWARDS PURSUA...
# 22          20140918106  <p style=text-align: center;"> &nbsp;</p> <p> ...
# 23          20140919101                                                NaN
# 24          20140919102                                                NaN
# 25          20140919103  <p> <strong>PUBLIC NOTICE IS HEREBY GIVEN </st...
# 26          20140922102  <p align=center"> <strong>New York City Depart...
# 27          20140923104                                                NaN
# 28          20140923106  <p style=text-align: center;"> &nbsp;</p> <p> ...
# 29          20140923107                                                NaN
# ..                  ...                                                ...
# 448         20141216121  <p> <strong>A PUBLIC HEARING </strong>is being...
# 449         20141216123                                                NaN
# 450         20141217104  <p align=center"> OFFICE OF THE MAYOR</p> <p a...
# 451         20141217105                                                NaN
# 452         20141217106  <p> <u>Notice of Intent to Issue New Solicitat...
# 453         20141218101  <p> <strong>NOTICE IS HEREBY GIVEN</strong> th...
# 454         20141218102  <p> <u>Notice of Intent to Issue New Solicitat...
# 455         20141219102  <p align=center"> <strong>Notice of Public Hea...
# 456         20141219103  <p> &nbsp;</p> <p align=center"> <strong>OFFIC...
# 457         20141219105                                                NaN
# 458         20141219106  <p align=center"> &nbsp;</p> <p> <strong>NOTIC...
# 459         20141219107  <p> <u>Notice of Intent to Issue New Solicitat...
# 460         20141219108  <p> <u>Notice of Intent to Issue New Solicitat...
# 461         20141219109  <p align=center"> COMMUTER VAN SERVICE AUTHORI...
# 462         20141219110  <p align=center"> <strong>COMMUTER VAN SERVICE...
# 463         20141219111  <p align=center"> <strong>COMMUTER VAN SERVICE...
# 464         20141219113  <p align=center"> <strong>COMMUTER VAN SERVICE...
# 465         20141222102                                                NaN
# 466         20141222103  <p> <u>Notice of Intent to Issue New Solicitat...
# 467         20141223102  <p> <u>Notice of Intent to Issue New Solicitat...
# 468         20141223103  <p align=center"> <strong>Corrected Notice of ...
# 469         20141223108  <p> <u>Notice of Intent to Issue New Solicitat...
# 470         20141224103                                                NaN
# 471         20141224104  <p> <u>Notice of Intent to Issue New Solicitat...
# 472         20141224105  <p> <u>Notice of Intent to Issue New Solicitat...
# 473         20141224106  <p> <u>Notice of Intent to Issue New Solicitat...
# 474         20141224109                                                NaN
# 475         20141226102  <p> &nbsp;</p> <p align=center"> <strong>JANUA...
# 476         20141229107  <p> Please take notice the first meeting of th...
# 477         20141229108                                                NaN
#
#      Address1                                             output
# 0         NaN                                               null
# 1         NaN                                               null
# 2         NaN                                               null
# 3         NaN                                               null
# 4         NaN                                               null
# 5         NaN                                               null
# 6         NaN                                               null
# 7         NaN                                               null
# 8         NaN                                               null
# 9         NaN                                               null
# 10        NaN                                               null
# 11        NaN                                               null
# 12        NaN                                               null
# 13        NaN                                               null
# 14        NaN                                               null
# 15        NaN                                               null
# 16        NaN                                               null
# 17        NaN                                               null
# 18        NaN                                               null
# 19        NaN                                               null
# 20        NaN                                               null
# 21        NaN                                               null
# 22        NaN                                               null
# 23        NaN                                               null
# 24        NaN                                               null
# 25        NaN                                               null
# 26        NaN                                               null
# 27        NaN                                               null
# 28        NaN                                               null
# 29        NaN                                               null
# ..        ...                                                ...
# 448       NaN                                               null
# 449       NaN                             {"error": "bad input"}
# 450       NaN                                               null
# 451       NaN                                               null
# 452       NaN  {"adverts": [{"Start date of the proposed cont...
# 453       NaN                                               null
# 454       NaN  {"adverts": [{"Start date of the proposed cont...
# 455       NaN                                               null
# 456       NaN                                               null
# 457       NaN                                               null
# 458       NaN                                               null
# 459       NaN  {"adverts": [{"Start date of the proposed cont...
# 460       NaN  {"adverts": [{"Start date of the proposed cont...
# 461       NaN                                               null
# 462       NaN                                               null
# 463       NaN                                               null
# 464       NaN                                               null
# 465       NaN                                               null
# 466       NaN  {"adverts": [{"Start date of the proposed cont...
# 467       NaN  {"adverts": [{"Start date of the proposed cont...
# 468       NaN                                               null
# 469       NaN  {"adverts": [{"Start date of the proposed cont...
# 470       NaN                                               null
# 471       NaN  {"adverts": [{"Start date of the proposed cont...
# 472       NaN  {"adverts": [{"Agency": "Department of Health ...
# 473       NaN  {"adverts": [{"Start date of the proposed cont...
# 474       NaN                                               null
# 475       NaN                                               null
# 476       NaN                                               null
# 477       NaN                                               null
#
# [478 rows x 16 columns]
